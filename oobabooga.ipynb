# %%
# !git clone https://github.com/oobabooga/text-generation-webui.git

# %%
# %cd text-generation-webui
# !pip install -r requirements.txt

# %%
# !python download-model.py mosaicml/mpt-7b

# %%
# !python server.py --share --trust-remote-code

# %%
# !pip install einops
